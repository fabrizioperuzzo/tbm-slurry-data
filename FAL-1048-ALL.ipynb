# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
from matplotlib.animation import FuncAnimation

# %%
import glob
from PIL import Image
from images2gif import writeGif
import IPython.display as IPdisplay

# %%
import shutil

# %%
# per matrice correlazione
import seaborn as sns
# Scipy helper functions
from scipy.stats import percentileofscore
from scipy import stats

# %%
import h5py

# %%
path = os.getcwd()+'\\DATA\\1048'

files = []
filespath = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.xls' in file:
            files.append(file)
            filespath.append(os.path.join(r, file))
            
# since there is only one file I need only the file name
os.path.join(r, files[0])
#check the first and last 5 files if correctly in list "files"
files[:5],files[-5:]
# Out:
# (['GEODATA_S-1048_RAW_20170821_28_-_week34.xls',
#   'GEODATA_S-1048_RAW_20170828_0904_-_week35.xls',
#   'GEODATA_S-1048_RAW_20170904_11_-_week36.xls',
#   'GEODATA_S-1048_RAW_20170911_18_-_week37.xls',
#   'GEODATA_S-1048_RAW_20170918_25_-_week38.xls'],
#  ['GEODATA_S-1048_RAW_20190603_0610_-_week23.xls',
#   'GEODATA_S-1048_RAW_20190617_0624_-_week25.xls',
#   'GEODATA_S-1048_RAW_20190624_0701_-_week26.xls',
#   'GEODATA_S-1048_RAW_20190701_0708_-_week27.xls',
#   'GEODATA_S-1048_RAW_20190907_0916_-_week_37.xls'])

# %%
dfxls=pd.DataFrame({})
n=0
for file in files:
    try:
        xlstemp = pd.read_excel(os.path.join(r, file), 'Sheet0')
        #xlstemp['CPTname']=file.replace('.xls','')
        dfxls = dfxls.append(xlstemp, ignore_index = True, sort=True)
        n+=1
        if n%10==0: print(n)
    except:
        print('A file was not loaded')
# %reset_selective -f "^xlstemp$"
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# 90

# %%
dfxls.shape
# Out:
# (5848115, 97)

# %%
dfxls.tail(3)
# Out:
#          AET Mass [t]  AET Volume [m³]  Advance speed [mm/min]  \
# 5848112        46.186           60.996                      39
# 5848113        46.746           61.790                      41
# 5848114        47.430           62.846                      39
#
#          Air Flow in Normal m3/min [m³/min]  \
# 5848112                                 0.0
# 5848113                                 0.0
# 5848114                                 0.0
#
#          Contact force shield articulation [kN]                 Date  \
# 5848112                                   16498  2019-09-16 06:58:30
# 5848113                                   16417  2019-09-16 06:59:00
# 5848114                                   16415  2019-09-16 06:59:30
#
#          Density feed line [t/m³]  Density slurry line [t/m³]  \
# 5848112                     1.170                       1.181
# 5848113                     1.171                       1.188
# 5848114                     1.172                       1.186
#
#          Excavated bentonite [m³]  \
# 5848112                       542
# 5848113                       551
# 5848114                       560
#
#          FS0011 Pressure transducer screw conveyor pump 1 high pressure [bar]  \
# 5848112                                             75.393
# 5848113                                             79.495
# 5848114                                             78.811
#
#          ...  Screw gate front closed [Bit]  Screw gate front open [Bit]  \
# 5848112  ...                              0                            1
# 5848113  ...                              0                            1
# 5848114  ...                              0                            1
#
#          Slurry circuit P04 density [t/m³]  Specific energy MJ/m3 [MJ/m³]  \
# 5848112                              1.193                             14
# 5848113                              1.186                             14
# 5848114                              1.188                             14
#
#          Speed screw conveyor from gear sensor [rpm]  \
# 5848112                                         13.4
# 5848113                                         13.4
# 5848114                                         13.3
#
#          Torque cutting wheel [MNm]  Torque screw conveyor calculated [-]  \
# 5848112                        2.50                                    33
# 5848113                        2.49                                    35
# 5848114                        2.41                                    34
#
#          Total advance force [kN]  Total amount of component A [l]  \
# 5848112                     16391                           4585.8
# 5848113                     16166                           4661.7
# 5848114                     16253                           4735.8
#
#          Total amount of component B [l]
# 5848112                            259.2
# 5848113                            263.7
# 5848114                            268.1
#
# [3 rows x 97 columns]

# %% [markdown]
# ### Controllo l'utilizzo della memoria e il numero di variabili utilizzate

# %%
import sys

# These are the usual ipython objects, including this one you are creating
ipython_vars = ['In', 'Out', 'exit', 'quit', 'get_ipython', 'ipython_vars']

# Get a sorted list of the objects and their sizes
sorted([(x, sys.getsizeof(globals().get(x))) for x in dir() if not x.startswith('_') and x not in sys.modules and x not in ipython_vars], key=lambda x: x[1], reverse=True)
# Out:
# [('dfxls', 4935118012),
#  ('dfxls_hdf', 1202100228),
#  ('xlstemp', 2430872),
#  ('rcParams', 9336),
#  ('rcParamsDefault', 9336),
#  ('rcParamsOrig', 9336),
#  ('sctypeDict', 4704),
#  ('typeDict', 4704),
#  ('sctypeNA', 2280),
#  ('typeNA', 2280),
#  ('finfo', 2000),
#  ('cast', 1200),
#  ('nbytes', 1200),
#  ('vectorize', 1184),
#  ('Annotation', 1056),
#  ('Arrow', 1056),
#  ('Artist', 1056),
#  ('AutoLocator', 1056),
#  ('Axes', 1056),
#  ('Axes3D', 1056),
#  ('AxisError', 1056),
#  ('Button', 1056),
#  ('Circle', 1056),
#  ('ComplexWarning', 1056),
#  ('DataSource', 1056),
#  ('DateFormatter', 1056),
#  ('DateLocator', 1056),
#  ('DayLocator', 1056),
#  ('Figure', 1056),
#  ('FigureCanvasBase', 1056),
#  ('FixedFormatter', 1056),
#  ('FixedLocator', 1056),
#  ('FormatStrFormatter', 1056),
#  ('Formatter', 1056),
#  ('FuncAnimation', 1056),
#  ('FuncFormatter', 1056),
#  ('GridSpec', 1056),
#  ('HourLocator', 1056),
#  ('IndexDateFormatter', 1056),
#  ('IndexLocator', 1056),
#  ('LinAlgError', 1056),
#  ('Line2D', 1056),
#  ('LinearLocator', 1056),
#  ('Locator', 1056),
#  ('LogFormatter', 1056),
#  ('LogFormatterExponent', 1056),
#  ('LogFormatterMathtext', 1056),
#  ('LogLocator', 1056),
#  ('MachAr', 1056),
#  ('MaxNLocator', 1056),
#  ('MinuteLocator', 1056),
#  ('ModuleDeprecationWarning', 1056),
#  ('MonthLocator', 1056),
#  ('MultipleLocator', 1056),
#  ('Normalize', 1056),
#  ('NullFormatter', 1056),
#  ('NullLocator', 1056),
#  ('PackageLoader', 1056),
#  ('PolarAxes', 1056),
#  ('Polygon', 1056),
#  ('RRuleLocator', 1056),
#  ('RankWarning', 1056),
#  ('Rectangle', 1056),
#  ('ScalarFormatter', 1056),
#  ('SecondLocator', 1056),
#  ('Slider', 1056),
#  ('Subplot', 1056),
#  ('SubplotTool', 1056),
#  ('Text', 1056),
#  ('TickHelper', 1056),
#  ('TooHardError', 1056),
#  ('VisibleDeprecationWarning', 1056),
#  ('WeekdayLocator', 1056),
#  ('Widget', 1056),
#  ('YearLocator', 1056),
#  ('chararray', 1056),
#  ('errstate', 1056),
#  ('format_parser', 1056),
#  ('iinfo', 1056),
#  ('matrix', 1056),
#  ('memmap', 1056),
#  ('ndenumerate', 1056),
#  ('ndindex', 1056),
#  ('poly1d', 1056),
#  ('recarray', 1056),
#  ('record', 1056),
#  ('relativedelta', 1056),
#  ('rrule', 1056),
#  ('silent_list', 1056),
#  ('strpdate2num', 1056),
#  ('f', 912),
#  ('files', 912),
#  ('filespath', 912),
#  ('Number', 888),
#  ('bool8', 400),
#  ('bool_', 400),
#  ('broadcast', 400),
#  ('busdaycalendar', 400),
#  ('byte', 400),
#  ('bytes', 400),
#  ('bytes0', 400),
#  ('bytes_', 400),
#  ('cdouble', 400),
#  ('cfloat', 400),
#  ('character', 400),
#  ('clongdouble', 400),
#  ('clongfloat', 400),
#  ('complex128', 400),
#  ('complex64', 400),
#  ('complex_', 400),
#  ('complexfloating', 400),
#  ('csingle', 400),
#  ('datetime64', 400),
#  ('double', 400),
#  ('dtype', 400),
#  ('flatiter', 400),
#  ('flexible', 400),
#  ('float16', 400),
#  ('float32', 400),
#  ('float64', 400),
#  ('float_', 400),
#  ('floating', 400),
#  ('generic', 400),
#  ('half', 400),
#  ('inexact', 400),
#  ('int0', 400),
#  ('int16', 400),
#  ('int32', 400),
#  ('int64', 400),
#  ('int8', 400),
#  ('int_', 400),
#  ('intc', 400),
#  ('integer', 400),
#  ('intp', 400),
#  ('long', 400),
#  ('longcomplex', 400),
#  ('longdouble', 400),
#  ('longfloat', 400),
#  ('longlong', 400),
#  ('ndarray', 400),
#  ('nditer', 400),
#  ('number', 400),
#  ('object0', 400),
#  ('object_', 400),
#  ('short', 400),
#  ('signedinteger', 400),
#  ('single', 400),
#  ('singlecomplex', 400),
#  ('str0', 400),
#  ('str_', 400),
#  ('string_', 400),
#  ('timedelta64', 400),
#  ('ubyte', 400),
#  ('ufunc', 400),
#  ('uint', 400),
#  ('uint0', 400),
#  ('uint16', 400),
#  ('uint32', 400),
#  ('uint64', 400),
#  ('uint8', 400),
#  ('uintc', 400),
#  ('uintp', 400),
#  ('ulonglong', 400),
#  ('unicode', 400),
#  ('unicode_', 400),
#  ('unsignedinteger', 400),
#  ('ushort', 400),
#  ('void', 400),
#  ('void0', 400),
#  ('typecodes', 368),
#  ('ScalarType', 304),
#  ('sctypes', 240),
#  ('absolute', 192),
#  ('add', 192),
#  ('arccos', 192),
#  ('arccosh', 192),
#  ('arcsin', 192),
#  ('arcsinh', 192),
#  ('arctan', 192),
#  ('arctan2', 192),
#  ('arctanh', 192),
#  ('bitwise_and', 192),
#  ('bitwise_not', 192),
#  ('bitwise_or', 192),
#  ('bitwise_xor', 192),
#  ('cbrt', 192),
#  ('ceil', 192),
#  ('conj', 192),
#  ('conjugate', 192),
#  ('copysign', 192),
#  ('cos', 192),
#  ('cosh', 192),
#  ('deg2rad', 192),
#  ('degrees', 192),
#  ('divide', 192),
#  ('divmod', 192),
#  ('equal', 192),
#  ('exp', 192),
#  ('exp2', 192),
#  ('expm1', 192),
#  ('fabs', 192),
#  ('float_power', 192),
#  ('floor', 192),
#  ('floor_divide', 192),
#  ('fmax', 192),
#  ('fmin', 192),
#  ('fmod', 192),
#  ('frexp', 192),
#  ('gcd', 192),
#  ('greater', 192),
#  ('greater_equal', 192),
#  ('heaviside', 192),
#  ('hypot', 192),
#  ('invert', 192),
#  ('isfinite', 192),
#  ('isinf', 192),
#  ('isnan', 192),
#  ('isnat', 192),
#  ('lcm', 192),
#  ('ldexp', 192),
#  ('left_shift', 192),
#  ('less', 192),
#  ('less_equal', 192),
#  ('log', 192),
#  ('log10', 192),
#  ('log1p', 192),
#  ('log2', 192),
#  ('logaddexp', 192),
#  ('logaddexp2', 192),
#  ('logical_and', 192),
#  ('logical_not', 192),
#  ('logical_or', 192),
#  ('logical_xor', 192),
#  ('maximum', 192),
#  ('minimum', 192),
#  ('mod', 192),
#  ('modf', 192),
#  ('multiply', 192),
#  ('negative', 192),
#  ('nextafter', 192),
#  ('not_equal', 192),
#  ('positive', 192),
#  ('rad2deg', 192),
#  ('radians', 192),
#  ('reciprocal', 192),
#  ('remainder', 192),
#  ('right_shift', 192),
#  ('rint', 192),
#  ('sign', 192),
#  ('signbit', 192),
#  ('sin', 192),
#  ('sinh', 192),
#  ('spacing', 192),
#  ('sqrt', 192),
#  ('square', 192),
#  ('subtract', 192),
#  ('tan', 192),
#  ('tanh', 192),
#  ('true_divide', 192),
#  ('trunc', 192),
#  ('path', 180),
#  ('r', 180),
#  ('acorr', 136),
#  ('add_newdoc', 136),
#  ('alen', 136),
#  ('all', 136),
#  ('allclose', 136),
#  ('alltrue', 136),
#  ('amap', 136),
#  ('amax', 136),
#  ('amin', 136),
#  ('angle', 136),
#  ('angle_spectrum', 136),
#  ('annotate', 136),
#  ('any', 136),
#  ('append', 136),
#  ('apply_along_axis', 136),
#  ('apply_over_axes', 136),
#  ('argmax', 136),
#  ('argmin', 136),
#  ('argpartition', 136),
#  ('argsort', 136),
#  ('argwhere', 136),
#  ('around', 136),
#  ('array2string', 136),
#  ('array_equal', 136),
#  ('array_equiv', 136),
#  ('array_repr', 136),
#  ('array_split', 136),
#  ('array_str', 136),
#  ('arrow', 136),
#  ('asanyarray', 136),
#  ('asarray', 136),
#  ('asarray_chkfinite', 136),
#  ('ascontiguousarray', 136),
#  ('asfarray', 136),
#  ('asfortranarray', 136),
#  ('asmatrix', 136),
#  ('asscalar', 136),
#  ('atleast_1d', 136),
#  ('atleast_2d', 136),
#  ('atleast_3d', 136),
#  ('autoscale', 136),
#  ('autumn', 136),
#  ('average', 136),
#  ('axes', 136),
#  ('axhline', 136),
#  ('axhspan', 136),
#  ('axis', 136),
#  ('axvline', 136),
#  ('axvspan', 136),
#  ('bar', 136),
#  ('barbs', 136),
#  ('barh', 136),
#  ('bartlett', 136),
#  ('base_repr', 136),
#  ('binary_repr', 136),
#  ('bivariate_normal', 136),
#  ('blackman', 136),
#  ('block', 136),
#  ('bmat', 136),
#  ('bone', 136),
#  ('box', 136),
#  ('boxplot', 136),
#  ('broadcast_arrays', 136),
#  ('broadcast_to', 136),
#  ('broken_barh', 136),
#  ('byte_bounds', 136),
#  ('center_matrix', 136),
#  ('cholesky', 136),
#  ('choose', 136),
#  ('cla', 136),
#  ('clabel', 136),
#  ('clf', 136),
#  ('clim', 136),
#  ('clip', 136),
#  ('close', 136),
#  ('cohere', 136),
#  ('colorbar', 136),
#  ('colormaps', 136),
#  ('column_stack', 136),
#  ('common_type', 136),
#  ('compress', 136),
#  ('cond', 136),
#  ('connect', 136),
#  ('contour', 136),
#  ('contourf', 136),
#  ('convolve', 136),
#  ('cool', 136),
#  ('copper', 136),
#  ('corrcoef', 136),
#  ('correlate', 136),
#  ('count_nonzero', 136),
#  ('cov', 136),
#  ('cross', 136),
#  ('csd', 136),
#  ('csv2rec', 136),
#  ('cumprod', 136),
#  ('cumproduct', 136),
#  ('cumsum', 136),
#  ('date2num', 136),
#  ('datestr2num', 136),
#  ('dedent', 136),
#  ('delaxes', 136),
#  ('delete', 136),
#  ('demean', 136),
#  ('deprecate', 136),
#  ('deprecate_with_doc', 136),
#  ('deprecated', 136),
#  ('det', 136),
#  ('detrend', 136),
#  ('detrend_linear', 136),
#  ('detrend_mean', 136),
#  ('detrend_none', 136),
#  ('diag', 136),
#  ('diag_indices', 136),
#  ('diag_indices_from', 136),
#  ('diagflat', 136),
#  ('diagonal', 136),
#  ('diff', 136),
#  ('disconnect', 136),
#  ('disp', 136),
#  ('dist', 136),
#  ('dist_point_to_segment', 136),
#  ('distances_along_curve', 136),
#  ('drange', 136),
#  ('draw', 136),
#  ('draw_if_interactive', 136),
#  ('dsplit', 136),
#  ('dstack', 136),
#  ('ediff1d', 136),
#  ('eig', 136),
#  ('eigh', 136),
#  ('eigvals', 136),
#  ('eigvalsh', 136),
#  ('einsum', 136),
#  ('einsum_path', 136),
#  ('entropy', 136),
#  ('epoch2num', 136),
#  ('errorbar', 136),
#  ('eventplot', 136),
#  ('exp_safe', 136),
#  ('expand_dims', 136),
#  ('extract', 136),
#  ('eye', 136),
#  ('fft', 136),
#  ('fft2', 136),
#  ('fftfreq', 136),
#  ('fftn', 136),
#  ('fftshift', 136),
#  ('fftsurr', 136),
#  ('figaspect', 136),
#  ('figimage', 136),
#  ('figlegend', 136),
#  ('fignum_exists', 136),
#  ('figtext', 136),
#  ('figure', 136),
#  ('fill', 136),
#  ('fill_between', 136),
#  ('fill_betweenx', 136),
#  ('fill_diagonal', 136),
#  ('find', 136),
#  ('find_common_type', 136),
#  ('findobj', 136),
#  ('fix', 136),
#  ('flag', 136),
#  ('flatnonzero', 136),
#  ('flatten', 136),
#  ('flip', 136),
#  ('fliplr', 136),
#  ('flipud', 136),
#  ('format_float_positional', 136),
#  ('format_float_scientific', 136),
#  ('frange', 136),
#  ('fromfunction', 136),
#  ('fromregex', 136),
#  ('full', 136),
#  ('full_like', 136),
#  ('fv', 136),
#  ('gca', 136),
#  ('gcf', 136),
#  ('gci', 136),
#  ('genfromtxt', 136),
#  ('geomspace', 136),
#  ('get', 136),
#  ('get_array_wrap', 136),
#  ('get_backend', 136),
#  ('get_cmap', 136),
#  ('get_current_fig_manager', 136),
#  ('get_figlabels', 136),
#  ('get_fignums', 136),
#  ('get_include', 136),
#  ('get_plot_commands', 136),
#  ('get_printoptions', 136),
#  ('get_scale_docs', 136),
#  ('get_scale_names', 136),
#  ('get_sparse_matrix', 136),
#  ('get_xyz_where', 136),
#  ('getbufsize', 136),
#  ('geterr', 136),
#  ('geterrcall', 136),
#  ('getp', 136),
#  ('ginput', 136),
#  ('gradient', 136),
#  ('gray', 136),
#  ('grid', 136),
#  ('griddata', 136),
#  ('hamming', 136),
#  ('hanning', 136),
#  ('hexbin', 136),
#  ('hfft', 136),
#  ('hist', 136),
#  ('hist2d', 136),
#  ('histogram', 136),
#  ('histogram2d', 136),
#  ('histogram_bin_edges', 136),
#  ('histogramdd', 136),
#  ('hlines', 136),
#  ('hot', 136),
#  ('hsplit', 136),
#  ('hstack', 136),
#  ('hsv', 136),
#  ('i0', 136),
#  ('identity', 136),
#  ('ifft', 136),
#  ('ifft2', 136),
#  ('ifftn', 136),
#  ('ifftshift', 136),
#  ('ihfft', 136),
#  ('imag', 136),
#  ('imread', 136),
#  ('imsave', 136),
#  ('imshow', 136),
#  ('in1d', 136),
#  ('indices', 136),
#  ('inferno', 136),
#  ('insert', 136),
#  ('inside_poly', 136),
#  ('install_repl_displayhook', 136),
#  ('interactive', 136),
#  ('interp', 136),
#  ('intersect1d', 136),
#  ('inv', 136),
#  ('ioff', 136),
#  ('ion', 136),
#  ('ipmt', 136),
#  ('irfft', 136),
#  ('irfft2', 136),
#  ('irfftn', 136),
#  ('irr', 136),
#  ('is_closed_polygon', 136),
#  ('isclose', 136),
#  ('iscomplex', 136),
#  ('iscomplexobj', 136),
#  ('isfortran', 136),
#  ('isin', 136),
#  ('isinteractive', 136),
#  ('isneginf', 136),
#  ('isposinf', 136),
#  ('ispower2', 136),
#  ('isreal', 136),
#  ('isrealobj', 136),
#  ('isscalar', 136),
#  ('issctype', 136),
#  ('issubclass_', 136),
#  ('issubdtype', 136),
#  ('issubsctype', 136),
#  ('isvector', 136),
#  ('iterable', 136),
#  ('ix_', 136),
#  ('jet', 136),
#  ('kaiser', 136),
#  ('kron', 136),
#  ('l1norm', 136),
#  ('l2norm', 136),
#  ('legend', 136),
#  ('linspace', 136),
#  ('load', 136),
#  ('loads', 136),
#  ('loadtxt', 136),
#  ('locator_params', 136),
#  ('loglog', 136),
#  ('logspace', 136),
#  ('longest_contiguous_ones', 136),
#  ('longest_ones', 136),
#  ('lookfor', 136),
#  ('lstsq', 136),
#  ('mafromtxt', 136),
#  ('magma', 136),
#  ('magnitude_spectrum', 136),
#  ('margins', 136),
#  ('mask_indices', 136),
#  ('mat', 136),
#  ('matrix_power', 136),
#  ('matrix_rank', 136),
#  ('matshow', 136),
#  ('maximum_sctype', 136),
#  ('mean', 136),
#  ('median', 136),
#  ('meshgrid', 136),
#  ('minorticks_off', 136),
#  ('minorticks_on', 136),
#  ('mintypecode', 136),
#  ('mirr', 136),
#  ('movavg', 136),
#  ('moveaxis', 136),
#  ('msort', 136),
#  ('multi_dot', 136),
#  ('mx2num', 136),
#  ('nan_to_num', 136),
#  ('nanargmax', 136),
#  ('nanargmin', 136),
#  ('nancumprod', 136),
#  ('nancumsum', 136),
#  ('nanmax', 136),
#  ('nanmean', 136),
#  ('nanmedian', 136),
#  ('nanmin', 136),
#  ('nanpercentile', 136),
#  ('nanprod', 136),
#  ('nanquantile', 136),
#  ('nanstd', 136),
#  ('nansum', 136),
#  ('nanvar', 136),
#  ('ndfromtxt', 136),
#  ('ndim', 136),
#  ('nipy_spectral', 136),
#  ('nonzero', 136),
#  ('norm', 136),
#  ('norm_flat', 136),
#  ('normpdf', 136),
#  ('nper', 136),
#  ('npv', 136),
#  ('num2date', 136),
#  ('num2epoch', 136),
#  ('obj2sctype', 136),
#  ('ones', 136),
#  ('ones_like', 136),
#  ('outer', 136),
#  ('pad', 136),
#  ('partition', 136),
#  ('path_length', 136),
#  ('pause', 136),
#  ('pcolor', 136),
#  ('pcolormesh', 136),
#  ('percentile', 136),
#  ('percentileofscore', 136),
#  ('phase_spectrum', 136),
#  ('pie', 136),
#  ('piecewise', 136),
#  ('pink', 136),
#  ('pinv', 136),
#  ('pkgload', 136),
#  ('place', 136),
#  ('plasma', 136),
#  ('plot', 136),
#  ('plot_date', 136),
#  ('plotfile', 136),
#  ('plotting', 136),
#  ('pmt', 136),
#  ('polar', 136),
#  ('poly', 136),
#  ('poly_below', 136),
#  ('poly_between', 136),
#  ('polyadd', 136),
#  ('polyder', 136),
#  ('polydiv', 136),
#  ('polyfit', 136),
#  ('polyint', 136),
#  ('polymul', 136),
#  ('polysub', 136),
#  ('polyval', 136),
#  ('ppmt', 136),
#  ('prctile', 136),
#  ('prctile_rank', 136),
#  ('printoptions', 136),
#  ('prism', 136),
#  ('prod', 136),
#  ('product', 136),
#  ('psd', 136),
#  ('ptp', 136),
#  ('put', 136),
#  ('put_along_axis', 136),
#  ('pv', 136),
#  ('pylab_setup', 136),
#  ('qr', 136),
#  ('quantile', 136),
#  ('quiver', 136),
#  ('quiverkey', 136),
#  ('rank', 136),
#  ('rate', 136),
#  ('ravel', 136),
#  ('rc', 136),
#  ('rc_context', 136),
#  ('rcdefaults', 136),
#  ('real', 136),
#  ('real_if_close', 136),
#  ('rec2csv', 136),
#  ('rec_append_fields', 136),
#  ('rec_drop_fields', 136),
#  ('rec_join', 136),
#  ('recfromcsv', 136),
#  ('recfromtxt', 136),
#  ('register_cmap', 136),
#  ('repeat', 136),
#  ('require', 136),
#  ('reshape', 136),
#  ('resize', 136),
#  ('rfft', 136),
#  ('rfft2', 136),
#  ('rfftfreq', 136),
#  ('rfftn', 136),
#  ('rgrids', 136),
#  ('rk4', 136),
#  ('rms_flat', 136),
#  ('roll', 136),
#  ('rollaxis', 136),
#  ('roots', 136),
#  ('rot90', 136),
#  ('round_', 136),
#  ('row_stack', 136),
#  ('safe_eval', 136),
#  ('save', 136),
#  ('savefig', 136),
#  ('savetxt', 136),
#  ('savez', 136),
#  ('savez_compressed', 136),
#  ('sca', 136),
#  ('scatter', 136),
#  ('sci', 136),
#  ('sctype2char', 136),
#  ('searchsorted', 136),
#  ('segments_intersect', 136),
#  ('semilogx', 136),
#  ('semilogy', 136),
#  ('set_cmap', 136),
#  ('set_printoptions', 136),
#  ('set_string_function', 136),
#  ('setbufsize', 136),
#  ('setdiff1d', 136),
#  ('seterr', 136),
#  ('seterrcall', 136),
#  ('setp', 136),
#  ('setxor1d', 136),
#  ('shape', 136),
#  ('show', 136),
#  ('show_config', 136),
#  ('sinc', 136),
#  ('size', 136),
#  ('slogdet', 136),
#  ('slopes', 136),
#  ('solve', 136),
#  ('sometrue', 136),
#  ('sort', 136),
#  ('sort_complex', 136),
#  ('source', 136),
#  ('specgram', 136),
#  ('split', 136),
#  ('spring', 136),
#  ('spy', 136),
#  ('squeeze', 136),
#  ('stack', 136),
#  ('stackplot', 136),
#  ('std', 136),
#  ('stem', 136),
#  ('step', 136),
#  ('stineman_interp', 136),
#  ('streamplot', 136),
#  ('subplot', 136),
#  ('subplot2grid', 136),
#  ('subplot_tool', 136),
#  ('subplots', 136),
#  ('subplots_adjust', 136),
#  ('sum', 136),
#  ('summer', 136),
#  ('suptitle', 136),
#  ('svd', 136),
#  ('swapaxes', 136),
#  ('switch_backend', 136),
#  ('table', 136),
#  ('take', 136),
#  ('take_along_axis', 136),
#  ('tensordot', 136),
#  ('tensorinv', 136),
#  ('tensorsolve', 136),
#  ('text', 136),
#  ('thetagrids', 136),
#  ('tick_params', 136),
#  ('ticklabel_format', 136),
#  ('tight_layout', 136),
#  ('tile', 136),
#  ('title', 136),
#  ('trace', 136),
#  ('transpose', 136),
#  ('trapz', 136),
#  ('tri', 136),
#  ('tricontour', 136),
#  ('tricontourf', 136),
#  ('tril', 136),
#  ('tril_indices', 136),
#  ('tril_indices_from', 136),
#  ('trim_zeros', 136),
#  ('tripcolor', 136),
#  ('triplot', 136),
#  ('triu', 136),
#  ('triu_indices', 136),
#  ('triu_indices_from', 136),
#  ('twinx', 136),
#  ('twiny', 136),
#  ('typename', 136),
#  ('uninstall_repl_displayhook', 136),
#  ('union1d', 136),
#  ('unique', 136),
#  ('unwrap', 136),
#  ('vander', 136),
#  ('var', 136),
#  ('vector_lengths', 136),
#  ('violinplot', 136),
#  ('viridis', 136),
#  ('vlines', 136),
#  ('vsplit', 136),
#  ('vstack', 136),
#  ('waitforbuttonpress', 136),
#  ('warn_deprecated', 136),
#  ('who', 136),
#  ('window_hanning', 136),
#  ('window_none', 136),
#  ('winter', 136),
#  ('writeGif', 136),
#  ('xcorr', 136),
#  ('xkcd', 136),
#  ('xlabel', 136),
#  ('xlim', 136),
#  ('xscale', 136),
#  ('xticks', 136),
#  ('ylabel', 136),
#  ('ylim', 136),
#  ('yscale', 136),
#  ('yticks', 136),
#  ('zeros_like', 136),
#  ('file', 95),
#  ('IPdisplay', 80),
#  ('Image', 80),
#  ('add_newdocs', 80),
#  ('cbook', 80),
#  ('char', 80),
#  ('cm', 80),
#  ('ctypeslib', 80),
#  ('docstring', 80),
#  ('emath', 80),
#  ('fftpack', 80),
#  ('fftpack_lite', 80),
#  ('helper', 80),
#  ('info', 80),
#  ('lapack_lite', 80),
#  ('linalg', 80),
#  ('ma', 80),
#  ('mlab', 80),
#  ('mpl', 80),
#  ('np', 80),
#  ('pd', 80),
#  ('plt', 80),
#  ('rcsetup', 80),
#  ('rec', 80),
#  ('sns', 80),
#  ('stats', 80),
#  ('style', 80),
#  ('FR', 72),
#  ('MO', 72),
#  ('SA', 72),
#  ('SU', 72),
#  ('TH', 72),
#  ('TU', 72),
#  ('WE', 72),
#  ('add_docstring', 72),
#  ('add_newdoc_ufunc', 72),
#  ('arange', 72),
#  ('beta', 72),
#  ('bincount', 72),
#  ('binomial', 72),
#  ('busday_count', 72),
#  ('busday_offset', 72),
#  ('can_cast', 72),
#  ('chisquare', 72),
#  ('choice', 72),
#  ('compare_chararrays', 72),
#  ('concatenate', 72),
#  ('copyto', 72),
#  ('datetime_as_string', 72),
#  ('datetime_data', 72),
#  ('digitize', 72),
#  ('dirichlet', 72),
#  ('dot', 72),
#  ('empty', 72),
#  ('empty_like', 72),
#  ('exponential', 72),
#  ('fastCopyAndTranspose', 72),
#  ('frombuffer', 72),
#  ('fromfile', 72),
#  ('fromiter', 72),
#  ('frompyfunc', 72),
#  ('fromstring', 72),
#  ('gamma', 72),
#  ('geometric', 72),
#  ('get_state', 72),
#  ('geterrobj', 72),
#  ('gumbel', 72),
#  ('hypergeometric', 72),
#  ('inner', 72),
#  ('int_asbuffer', 72),
#  ('is_busday', 72),
#  ('laplace', 72),
#  ('lexsort', 72),
#  ('logistic', 72),
#  ('lognormal', 72),
#  ('logseries', 72),
#  ('matmul', 72),
#  ('may_share_memory', 72),
#  ('min_scalar_type', 72),
#  ('multinomial', 72),
#  ('multivariate_normal', 72),
#  ('negative_binomial', 72),
#  ('nested_iters', 72),
#  ('noncentral_chisquare', 72),
#  ('noncentral_f', 72),
#  ('normal', 72),
#  ('packbits', 72),
#  ('pareto', 72),
#  ('permutation', 72),
#  ('poisson', 72),
#  ('power', 72),
#  ('promote_types', 72),
#  ('putmask', 72),
#  ('rand', 72),
#  ('randint', 72),
#  ('randn', 72),
#  ('random_integers', 72),
#  ('random_sample', 72),
#  ('ranf', 72),
#  ('ravel_multi_index', 72),
#  ('rayleigh', 72),
#  ('result_type', 72),
#  ('sample', 72),
#  ('seed', 72),
#  ('set_numeric_ops', 72),
#  ('set_state', 72),
#  ('seterrobj', 72),
#  ('shares_memory', 72),
#  ('shuffle', 72),
#  ('standard_cauchy', 72),
#  ('standard_exponential', 72),
#  ('standard_gamma', 72),
#  ('standard_normal', 72),
#  ('standard_t', 72),
#  ('triangular', 72),
#  ('uniform', 72),
#  ('unpackbits', 72),
#  ('unravel_index', 72),
#  ('vdot', 72),
#  ('vonmises', 72),
#  ('wald', 72),
#  ('weibull', 72),
#  ('where', 72),
#  ('zeros', 72),
#  ('zipf', 72),
#  ('d', 64),
#  ('draw_all', 64),
#  ('new_figure_manager', 64),
#  ('UFUNC_PYVALS_NAME', 61),
#  ('absolute_import', 56),
#  ('c_', 56),
#  ('division', 56),
#  ('index_exp', 56),
#  ('mgrid', 56),
#  ('ogrid', 56),
#  ('print_function', 56),
#  ('r_', 56),
#  ('s_', 56),
#  ('test', 56),
#  ('ALLOW_THREADS', 28),
#  ('BUFSIZE', 28),
#  ('DAILY', 28),
#  ('ERR_CALL', 28),
#  ('ERR_DEFAULT', 28),
#  ('ERR_LOG', 28),
#  ('ERR_PRINT', 28),
#  ('ERR_RAISE', 28),
#  ('ERR_WARN', 28),
#  ('FLOATING_POINT_SUPPORT', 28),
#  ('FPE_DIVIDEBYZERO', 28),
#  ('FPE_INVALID', 28),
#  ('FPE_OVERFLOW', 28),
#  ('FPE_UNDERFLOW', 28),
#  ('HOURLY', 28),
#  ('MAXDIMS', 28),
#  ('MAY_SHARE_EXACT', 28),
#  ('MINUTELY', 28),
#  ('MONTHLY', 28),
#  ('RAISE', 28),
#  ('SECONDLY', 28),
#  ('SHIFT_INVALID', 28),
#  ('SHIFT_OVERFLOW', 28),
#  ('SHIFT_UNDERFLOW', 28),
#  ('UFUNC_BUFSIZE_DEFAULT', 28),
#  ('WEEKLY', 28),
#  ('WRAP', 28),
#  ('little_endian', 28),
#  ('n', 28),
#  ('tracemalloc_domain', 28),
#  ('False_', 25),
#  ('True_', 25),
#  ('CLIP', 24),
#  ('ERR_IGNORE', 24),
#  ('Inf', 24),
#  ('Infinity', 24),
#  ('MAY_SHARE_BOUNDS', 24),
#  ('NAN', 24),
#  ('NINF', 24),
#  ('NZERO', 24),
#  ('NaN', 24),
#  ('PINF', 24),
#  ('PZERO', 24),
#  ('SHIFT_DIVIDEBYZERO', 24),
#  ('YEARLY', 24),
#  ('e', 24),
#  ('euler_gamma', 24),
#  ('inf', 24),
#  ('infty', 24),
#  ('nan', 24),
#  ('pi', 24),
#  ('newaxis', 16)]

# %% [markdown]
# Cancello le variabili che non uso

# %%
dfxls.memory_usage(deep=True).sum()

# %% [markdown]
# ### SALVO IL DATABASE NEL FORMATO COMPRESSO H5

# %%
# Prima di salcare semplifico i nomi delle colonne

dfxls.columns = list(map(lambda x : str(x).replace(" ",""), dfxls.columns))
dfxls.columns = list(map(lambda x : str(x).replace("Pressure","_Pres_"), dfxls.columns))
dfxls.columns = list(map(lambda x : str(x).replace("pressure","_pres_"), dfxls.columns))
dfxls.columns = list(map(lambda x : str(x).replace("conveyor","conv"), dfxls.columns))

dfxls.columns.tolist()[:3]
# Out:
# ['AETMass[t]', 'AETVolume[m³]', 'Advancespeed[mm/min]']

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c9f0b8c65221> in <module>
# ----> 1 import h5py
#
# ModuleNotFoundError: No module named 'h5py'

# %%
dfxls.dropna().to_hdf('ALL2.h5', key='losses')
# Out:
# C:\ProgramData\Anaconda3_1\lib\site-packages\pandas\core\generic.py:2530: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->['Date']]
#
#   pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %% [markdown]
# ### SALVO IL DATABASE DI GENNAIO

# %%
xlstemp = pd.read_excel(os.path.join(r, 'GEODATA_S-1048_RAW_20200107.xls'), 'Sheet0')

# %%
xlstemp.dropna().to_hdf('ALL_202001.h5', key='losses')

# %% [markdown]
# ### CARICO IL FILE DA H5 -- VELOCE

# %%
# Pulisco la memoria
# %reset_selective -f "^xls$"
# %reset_selective -f "^xlstemp$"
# %reset_selective -f "^dfxls_hdf$"
# %reset_selective -f "^dfxls$"

# %%
dfxls = pd.read_hdf('ALL2.h5', key='losses')

# %%
dfxls.shape
# Out:
# (1411727, 97)

# %%
####   TUTTI I NOMI DELLE COLONNE LOWER CASE
dfxls.columns = map(str.lower, dfxls.columns)
dfxls.columns = dfxls.columns.str.replace('s-1048_advance_advance_no','advance_no')

# %%
dfxls = dfxls.filter(regex='(excavationchamber|date|filllevel|groutinjection_pres_|mnm|advance|mm/min)')
dfxls.tail()
# Out:
#                         date           datestamp  advance_no[-]  \
# 5848110  2019-09-16 06:57:30 2019-09-16 06:57:30         3404.0
# 5848111  2019-09-16 06:58:00 2019-09-16 06:58:00         3404.0
# 5848112  2019-09-16 06:58:30 2019-09-16 06:58:30         3404.0
# 5848113  2019-09-16 06:59:00 2019-09-16 06:59:00         3404.0
# 5848114  2019-09-16 06:59:30 2019-09-16 06:59:30         3404.0
#
#          _pres_excavationchamber1[bar]  _pres_excavationchamber2[bar]  \
# 5848110                          1.975                          2.193
# 5848111                          1.982                          2.167
# 5848112                          1.986                          2.189
# 5848113                          1.972                          2.159
# 5848114                          1.963                          2.159
#
#          _pres_excavationchamber3[bar]  _pres_excavationchamber4[bar]  \
# 5848110                          2.351                          2.394
# 5848111                          2.319                          2.413
# 5848112                          2.316                          2.460
# 5848113                          2.265                          2.427
# 5848114                          2.385                          2.383
#
#          _pres_excavationchamber5[bar]  _pres_excavationchamber6[bar]  \
# 5848110                          2.414                          2.250
# 5848111                          2.436                          2.268
# 5848112                          2.430                          2.275
# 5848113                          2.429                          2.263
# 5848114                          2.407                          2.250
#
#          _pres_excavationchamber7[bar]  _pres_excavationchamber8[bar]  \
# 5848110                          1.973                          1.909
# 5848111                          1.985                          1.910
# 5848112                          1.995                          1.926
# 5848113                          1.983                          1.913
# 5848114                          1.966                          1.901
#
#          filllevelworkingchamber[m]  advancespeed[mm/min]  \
# 5848110                       0.384                    40
# 5848111                       0.407                    40
# 5848112                       0.445                    39
# 5848113                       0.480                    41
# 5848114                       0.493                    39
#
#          totaladvanceforce[kn]  torquecuttingwheel[mnm]  \
# 5848110                  16232                     2.56
# 5848111                  16290                     2.47
# 5848112                  16391                     2.50
# 5848113                  16166                     2.49
# 5848114                  16253                     2.41
#
#          line1groutinjection_pres_[bar]  line2groutinjection_pres_[bar]  \
# 5848110                           2.753                           2.618
# 5848111                           2.661                           2.576
# 5848112                           2.741                           2.576
# 5848113                           2.765                           2.600
# 5848114                           2.875                           2.661
#
#          line3groutinjection_pres_[bar]  line4groutinjection_pres_[bar]
# 5848110                           3.308                           4.822
# 5848111                           3.290                           4.822
# 5848112                           3.308                           4.834
# 5848113                           3.351                           4.840
# 5848114                           3.369                           5.017

# %% [markdown]
# Creo una colonna con formati date riconoscibili da python

# %%
dfxls['datestamp']=pd.to_datetime(dfxls.date)
dfxls['timestamp']=dfxls.datestamp.apply(lambda x: int(time.mktime(x.timetuple())))
dfxls.sort_values('timestamp',inplace=True)

# %%
dfxls.columns.tolist()
# Out:
# ['advancespeed[mm/min]',
#  'date',
#  'filllevelworkingchamber[m]',
#  'line1groutinjection_pres_[bar]',
#  'line2groutinjection_pres_[bar]',
#  'line3groutinjection_pres_[bar]',
#  'line4groutinjection_pres_[bar]',
#  '_pres_excavationchamber1[bar]',
#  '_pres_excavationchamber2[bar]',
#  '_pres_excavationchamber3[bar]',
#  '_pres_excavationchamber4[bar]',
#  '_pres_excavationchamber5[bar]',
#  '_pres_excavationchamber6[bar]',
#  '_pres_excavationchamber7[bar]',
#  '_pres_excavationchamber8[bar]',
#  's-1048_advance_advance_no[-]',
#  'torquecuttingwheel[mnm]',
#  'totaladvanceforce[kn]',
#  'datestamp',
#  'timestamp']

# %%
dfxls = dfxls[['date','datestamp','timestamp','s-1048_advance_advance_no[-]',
 '_pres_excavationchamber1[bar]',
 '_pres_excavationchamber2[bar]',
 '_pres_excavationchamber3[bar]',
 '_pres_excavationchamber4[bar]',
 '_pres_excavationchamber5[bar]',
 '_pres_excavationchamber6[bar]',
 '_pres_excavationchamber7[bar]',
 '_pres_excavationchamber8[bar]',
 'filllevelworkingchamber[m]',               
 'advancespeed[mm/min]',
 'totaladvanceforce[kn]',
 'torquecuttingwheel[mnm]', 
 'line1groutinjection_pres_[bar]',
 'line2groutinjection_pres_[bar]',
 'line3groutinjection_pres_[bar]',
 'line4groutinjection_pres_[bar]',
]]

# %%
dfxls
# Out:
#                         date           datestamp   timestamp  \
# 4098490  2018-12-08 15:41:40 2018-12-08 15:41:40  1544280100
# 4098491  2018-12-08 15:41:50 2018-12-08 15:41:50  1544280110
# 4098492  2018-12-08 15:42:00 2018-12-08 15:42:00  1544280120
# 4098493  2018-12-08 15:42:10 2018-12-08 15:42:10  1544280130
# 4098494  2018-12-08 15:42:20 2018-12-08 15:42:20  1544280140
# ...                      ...                 ...         ...
# 5848110  2019-09-16 06:57:30 2019-09-16 06:57:30  1568609850
# 5848111  2019-09-16 06:58:00 2019-09-16 06:58:00  1568609880
# 5848112  2019-09-16 06:58:30 2019-09-16 06:58:30  1568609910
# 5848113  2019-09-16 06:59:00 2019-09-16 06:59:00  1568609940
# 5848114  2019-09-16 06:59:30 2019-09-16 06:59:30  1568609970
#
#          s-1048_advance_advance_no[-]  _pres_excavationchamber1[bar]  \
# 4098490                        2256.0                          1.778
# 4098491                        2256.0                          1.746
# 4098492                        2256.0                          1.756
# 4098493                        2256.0                          1.775
# 4098494                        2256.0                          1.781
# ...                               ...                            ...
# 5848110                        3404.0                          1.975
# 5848111                        3404.0                          1.982
# 5848112                        3404.0                          1.986
# 5848113                        3404.0                          1.972
# 5848114                        3404.0                          1.963
#
#          _pres_excavationchamber2[bar]  _pres_excavationchamber3[bar]  \
# 4098490                          1.935                          2.048
# 4098491                          1.906                          2.019
# 4098492                          1.912                          2.024
# 4098493                          1.935                          2.046
# 4098494                          1.938                          2.055
# ...                                ...                            ...
# 5848110                          2.193                          2.351
# 5848111                          2.167                          2.319
# 5848112                          2.189                          2.316
# 5848113                          2.159                          2.265
# 5848114                          2.159                          2.385
#
#          _pres_excavationchamber4[bar]  _pres_excavationchamber5[bar]  \
# 4098490                          2.171                          2.237
# 4098491                          2.149                          2.244
# 4098492                          2.156                          2.250
# 4098493                          2.165                          2.244
# 4098494                          2.165                          2.265
# ...                                ...                            ...
# 5848110                          2.394                          2.414
# 5848111                          2.413                          2.436
# 5848112                          2.460                          2.430
# 5848113                          2.427                          2.429
# 5848114                          2.383                          2.407
#
#          _pres_excavationchamber6[bar]  _pres_excavationchamber7[bar]  \
# 4098490                          2.202                          1.805
# 4098491                          2.093                          1.780
# 4098492                          2.000                          1.773
# 4098493                          2.087                          1.805
# 4098494                          2.073                          1.821
# ...                                ...                            ...
# 5848110                          2.250                          1.973
# 5848111                          2.268                          1.985
# 5848112                          2.275                          1.995
# 5848113                          2.263                          1.983
# 5848114                          2.250                          1.966
#
#          _pres_excavationchamber8[bar]  filllevelworkingchamber[m]  \
# 4098490                          1.677                      -0.170
# 4098491                          1.647                      -0.175
# 4098492                          1.652                      -0.179
# 4098493                          1.677                      -0.181
# 4098494                          1.679                      -0.185
# ...                                ...                         ...
# 5848110                          1.909                       0.384
# 5848111                          1.910                       0.407
# 5848112                          1.926                       0.445
# 5848113                          1.913                       0.480
# 5848114                          1.901                       0.493
#
#          advancespeed[mm/min]  totaladvanceforce[kn]  torquecuttingwheel[mnm]  \
# 4098490                    24                  17250                     2.48
# 4098491                    25                  17087                     2.63
# 4098492                    26                  17023                     2.52
# 4098493                    25                  17026                     2.53
# 4098494                    25                  17022                     2.57
# ...                       ...                    ...                      ...
# 5848110                    40                  16232                     2.56
# 5848111                    40                  16290                     2.47
# 5848112                    39                  16391                     2.50
# 5848113                    41                  16166                     2.49
# 5848114                    39                  16253                     2.41
#
#          line1groutinjection_pres_[bar]  line2groutinjection_pres_[bar]  \
# 4098490                           3.021                           4.492
# 4098491                           3.027                           4.486
# 4098492                           3.021                           4.474
# 4098493                           2.997                           4.462
# 4098494                           3.009                           4.474
# ...                                 ...                             ...
# 5848110                           2.753                           2.618
# 5848111                           2.661                           2.576
# 5848112                           2.741                           2.576
# 5848113                           2.765                           2.600
# 5848114                           2.875                           2.661
#
#          line3groutinjection_pres_[bar]  line4groutinjection_pres_[bar]
# 4098490                           2.686                           3.003
# 4098491                           2.686                           3.003
# 4098492                           2.686                           2.973
# 4098493                           2.673                           2.973
# 4098494                           2.692                           2.954
# ...                                 ...                             ...
# 5848110                           3.308                           4.822
# 5848111                           3.290                           4.822
# 5848112                           3.308                           4.834
# 5848113                           3.351                           4.840
# 5848114                           3.369                           5.017
#
# [1411727 rows x 20 columns]

# %%
# cerco la posizione del fill level

pos_filllev=int(dfxls.columns.get_loc(dfxls.filter(regex='level').columns.tolist()[0]))
pos_filllev
# Out:
# 12

# %%
# creo una lista con le posizioni dei sensori delle camere
list_chamb = []
for i in dfxls.filter(regex='Pressure excavation chamber'):
    list_chamb.append(dfxls.columns.get_loc(i))
print(list_chamb)

list_col = [0]
list_col.extend(list_chamb)
list_col.append(pos_filllev)
print(list_col)

# %%
print(plt.style.available)

# %%
num_dati = -1

df = dfxls.iloc[:num_dati,list_col]
n_row = df.shape[0]



# *************************************************

n_sensori = 8
list_x = []
list_z = []
for i in np.arange(0,n_sensori,1):
    x = 1 * np.sin(2*np.pi/8*i)
    list_x.append(x)
    z = 1 * np.cos(2*np.pi/8*i)
    list_z.append(z)

    
#  ************************************************



plt.style.use('dark_background')

shutil.rmtree('images', ignore_errors=True)
save_folder = 'images/gif'
gif_filename = '01'

working_folder = '{}/{}'.format(save_folder, gif_filename)

if not os.path.exists(working_folder):
    os.makedirs(working_folder)

fontdict1={'fontsize': 18,
          'fontweight':0.1,
          'horizontalalignment': 'center'}

fontdict2 = {'family': 'serif',
        'color':  'white',
        'weight': 'normal',
        'size': 16,
        }

for e in np.arange(0,n_row,1):
    
    if e%10==0:    # creo immagine ogni 10 print
        try:
            ax.clear()
            ax1.clear()
        except:
            pass
        fig = plt.figure(figsize=(20,10))

        ax = fig.add_subplot(121, projection='3d')
        ax1 = fig.add_subplot(122, projection='3d')

        ax.set_xlabel("x")
        ax.set_ylabel("y") 
        ax.set_zlabel("z")

        ax.view_init(45, -45) # rotazione della vista 3d

        ax.set_xlim3d(-1,1)
        ax.set_ylim3d(1.5,0) # same as saying to invert it 
        ax.set_zlim3d(-1,1) 

        #######      *********

        ax1.set_xlim3d(-1,1)
        ax1.set_ylim3d(-1,1) # same as saying to invert it 
        ax1.set_zlim3d(0,3) 



        ax.set_xlabel('x'),ax.set_ylabel('Pressure [bar]'),ax.set_zlabel('y')

        n_row = df.shape[0]

        for i in np.arange(0,n_sensori,1):

            x_ = list_x[i]
            z_ = list_z[i]
            y_ = df.iloc[e,i+1]-1   # tolgo 1bar per renderle omogenee
            z1_ = df.iloc[e,-1]*3   # tmopltiplico *3



            ax.bar3d(x_, y_, z_, dx=0.2, dz=0.2, dy=(0-y_),
                    color='deepskyblue')


        ax1.bar3d(0, 0, z1_, dx=0.5, dy=0.5, dz=(0-z1_),
                    color='r')

        ax.text2D(0.05, 0.99, str(df.iloc[e,0]), transform=ax.transAxes, fontdict = fontdict2)

        ax.text2D(0.05, 0, str('Pressure chamber'), transform=ax.transAxes, fontdict = fontdict2)
        ax1.text2D(2, 0, str('Fill Level'), transform=ax.transAxes, fontdict = fontdict2)
    
    
        plt.savefig('{}/{}/img{:03d}.png'.format(save_folder, gif_filename, e))    
        
        
    
# don't display the static plot...
plt.close()

# load all the static images into a list then save as an animated gif
gif_filepath = '{}/{}.gif'.format(save_folder, gif_filename)

images = []
images = [Image.open(image) for image in glob.glob('{}/*.png'.format(working_folder))]
gif = images[0]
gif.info['duration'] = 75 #milliseconds per frame
gif.info['loop'] = 0 #how many times to loop (0=infinite)
append_images=[]
gif.save(fp=gif_filepath, format='gif', save_all=True, append_images=images[1:])
IPdisplay.Image(url=gif_filepath)

# %%
dfxls.columns.tolist()

# %%
#dfg = dfxls.iloc[:,[2,4,6,9,10,11,19,20,22,26,27,30,32,33,34,37,50,51]]
dfg = dfxls.iloc[:,[2,4,6,9,10,11,19,20,22,26,27,30,32]]
dfg.columns

# %%
# Calculate correlation coefficient
def corrfunc(x, y, **kws):
    r, _ = stats.pearsonr(x, y)
    ax = plt.gca()
    ax.annotate("r = {:.2f}".format(r),
                xy=(.1, .6), xycoords=ax.transAxes,
               size = 20)
    
plt.style.use('seaborn-pastel')   
sns.set_style("white")
    
cmap = sns.cubehelix_palette(light=1, dark = 0.1,
                             hue = 0.5, as_cmap=True)

sns.set_context(font_scale=2)

fig = plt.figure(figsize=(30,30))
sns.set(rc={'figure.figsize':(30,30)})


# Pair grid set up
g = sns.PairGrid(dfg)

# Scatter plot on the upper triangle
g.map_upper(plt.scatter, s=10, color = 'b')

# Distribution on the diagonal
g.map_diag(sns.distplot, kde=False, color = 'red')

# Density Plot and Correlation coefficients on the lower triangle
g.map_lower(sns.kdeplot, cmap = cmap)
g.map_lower(corrfunc);

plt.savefig('{}/{}/img_{}.png'.format(save_folder, gif_filename, 'corr_matrix'))

# %% [markdown]
# ## Creo una funzione per plottare in automatico il multigrafico di correlazione

# %%
def corrfunc(x, y, **kws):
    r, _ = stats.pearsonr(x, y)
    ax = plt.gca()
    ax.annotate("r = {:.2f}".format(r),
                xy=(.1, .6), xycoords=ax.transAxes,
               size = 20)

def corrgraph(dfg, nomefile):
    # Function to create graph correlation matrix

    plt.style.use('seaborn-pastel')   
    sns.set_style("white")

    cmap = sns.cubehelix_palette(light=1, dark = 0.1,
                                 hue = 0.5, as_cmap=True)

    sns.set_context(font_scale=2)

    fig = plt.figure(figsize=(30,30))
    sns.set(rc={'figure.figsize':(30,30)})


    # Pair grid set up
    g = sns.PairGrid(dfg)

    # Scatter plot on the upper triangle
    g.map_upper(plt.scatter, s=10, color = 'b')

    # Distribution on the diagonal
    g.map_diag(sns.distplot, kde=False, color = 'red')

    # Density Plot and Correlation coefficients on the lower triangle
    g.map_lower(sns.kdeplot, cmap = cmap)
    g.map_lower(corrfunc);

    plt.savefig('{}/{}/img_{}.png'.format(save_folder, gif_filename, nomefile))

# %% [markdown]
# ### Plotto il multigrafico per i dati delle pressure chamber e il Fill level

# %%
dfg=dfxls.filter(regex='(Pressure excavation chamber|Fill level)')

col_ls = dfg.columns.tolist()
col_ls = list(map(lambda x: str.replace(x,"Pressure excavation chamber ","Pr_Ex_Ch_"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Fill level working chamber","Fill_Lev_WCh"),col_ls))
dfg.columns = col_ls

# %%
corrgraph(dfg, 'corr_2')

# %%
f, ax = plt.subplots(figsize=(10,8))
corr = dfg.corr()
sns.heatmap(corr,
           xticklabels=corr.columns.values,
           yticklabels=corr.columns.values)

# %%
#  Seleziono colonne utili

dfg=dfxls.filter(regex='(Pressure excavation chamber 5|Pressure excavation chamber 8|Fill level|grout injection pressure|\
grout injection amount|grout injection flow|Air Flow in Normal)')

# Semplifico il nome delle colonne
col_ls = dfg.columns.tolist()
col_ls = list(map(lambda x: str.replace(x,"Pressure excavation chamber ","Pr_Ex_Ch_"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Fill level working chamber","Fill_Lev_WCh"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Air Flow in Normal m3/min","Air_Flow_in"),col_ls))
col_ls = list(map(lambda x: str.replace(x," grout injection ","_Gr_in_"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"pressure","Pr"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Line ","L_"),col_ls))
dfg.columns = col_ls

# Verifico i risultati dell'operazione
col_ls

# %%
corrgraph(dfg, 'corr_2')

# %%
#  Seleziono colonne utili

dfg=dfxls.filter(regex='(Pressure excavation chamber 5|Pressure excavation chamber 8|Fill level|grout injection pressure|\
Line 1 grout injection amount|Line 1 grout injection flow)')

# Semplifico il nome delle colonne
col_ls = dfg.columns.tolist()
col_ls = list(map(lambda x: str.replace(x,"Pressure excavation chamber ","Pr_Ex_Ch_"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Fill level working chamber","Fill_Lev_WCh"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Air Flow in Normal m3/min","Air_Flow_in"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Line 1 grout injection ","L1_Gr_in_"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"pressure","Pr"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Line ","L_"),col_ls))
dfg.columns = col_ls

# Verifico i risultati dell'operazione
col_ls

# %%
corrgraph(dfg, 'corr_2')

# %%
import scipy.stats as st
import statsmodels as sm
import matplotlib as mpl
import matplotlib.pyplot as plt

matplotlib.rcParams['figure.figsize'] = (16.0, 12.0)
#matplotlib.style.use('ggplot')

# Create models from data
def best_fit_distribution(data, bins=10, ax=None):
    """Model data by finding best fit distribution to data"""
    # Get histogram of original data
    y, x = np.histogram(data, bins=bins, density=True)
    x = (x + np.roll(x, -1))[:-1] / 2.0

    # Distributions to check
    DISTRIBUTIONS = [        
        st.alpha,st.anglit,st.arcsine,st.beta,st.betaprime,st.bradford,st.burr,st.cauchy,st.chi,st.chi2,st.cosine,
        st.dgamma,st.dweibull,st.erlang,st.expon,st.exponnorm,st.exponweib,st.exponpow,st.f,st.fatiguelife,st.fisk,
        st.foldcauchy,st.foldnorm,st.frechet_r,st.frechet_l,st.genlogistic,st.genpareto,st.gennorm,st.genexpon,
        st.genextreme,st.gausshyper,st.gamma,st.gengamma,st.genhalflogistic,st.gilbrat,st.gompertz,st.gumbel_r,
        st.gumbel_l,st.halfcauchy,st.halflogistic,st.halfnorm,st.halfgennorm,st.hypsecant,st.invgamma,st.invgauss,
        st.invweibull,st.johnsonsb,st.johnsonsu,st.ksone,st.kstwobign,st.laplace,st.levy,st.levy_l,st.levy_stable,
        st.logistic,st.loggamma,st.loglaplace,st.lognorm,st.lomax,st.maxwell,st.mielke,st.nakagami,st.ncx2,st.ncf,
        st.nct,st.norm,st.pareto,st.pearson3,st.powerlaw,st.powerlognorm,st.powernorm,st.rdist,st.reciprocal,
        st.rayleigh,st.rice,st.recipinvgauss,st.semicircular,st.t,st.triang,st.truncexpon,st.truncnorm,st.tukeylambda,
        st.uniform,st.vonmises,st.vonmises_line,st.wald,st.weibull_min,st.weibull_max,st.wrapcauchy]


    # Best holders
    best_distribution = st.norm
    best_params = (0.0, 1.0)
    best_sse = np.inf

    # Estimate distribution parameters from data
    for distribution in DISTRIBUTIONS:

        # Try to fit the distribution
        try:
            # Ignore warnings from data that can't be fit
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore')

                # fit dist to data
                params = distribution.fit(data)

                # Separate parts of parameters
                arg = params[:-2]
                loc = params[-2]
                scale = params[-1]

                # Calculate fitted PDF and error with fit in distribution
                pdf = distribution.pdf(x, loc=loc, scale=scale, *arg)
                sse = np.sum(np.power(y - pdf, 2.0))

                # if axis pass in add to plot
                try:
                    if ax:
                        pd.Series(pdf, x).plot(ax=ax)
                    end
                except Exception:
                    pass

                # identify if this distribution is better
                if best_sse > sse > 0:
                    best_distribution = distribution
                    best_params = params
                    best_sse = sse

        except Exception:
            pass

    return (best_distribution.name, best_params)

def make_pdf(dist, params, size=10000):
    """Generate distributions's Probability Distribution Function """

    # Separate parts of parameters
    arg = params[:-2]
    loc = params[-2]
    scale = params[-1]

    # Get sane start and end points of distribution
    start = dist.ppf(0.01, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.01, loc=loc, scale=scale)
    end = dist.ppf(0.99, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.99, loc=loc, scale=scale)

    # Build PDF and turn into pandas Series
    x = np.linspace(start, end, size)
    y = dist.pdf(x, loc=loc, scale=scale, *arg)
    pdf = pd.Series(y, x)

    return pdf

# %%
###     CREATE LAST DF

# %%
#  Seleziono colonne utili

dfg=dfxls.filter(regex='(Pressure excavation chamber 5|Pressure excavation chamber 8|Fill level|grout injection pressure|\
Line 1 grout injection amount|Line 1 grout injection flow)')

# Semplifico il nome delle colonne
col_ls = dfg.columns.tolist()
col_ls = list(map(lambda x: str.replace(x,"Pressure excavation chamber ","Pr_Ex_Ch_"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Fill level working chamber","Fill_Lev_WCh"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Air Flow in Normal m3/min","Air_Flow_in"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Line 1 grout injection ","L1_Gr_in_"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"pressure","Pr"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Line ","L_"),col_ls))
dfg.columns = col_ls

# Verifico i risultati dell'operazione
print (col_ls)

# %%
# Load data from statsmodels datasets plot best fit distribution

#data = pd.Series(sm.datasets.elnino.load_pandas().data.set_index('YEAR').values.ravel())

dfg_1 = dfg.copy() # .copy() avoid regressive modifications

n_cols = dfg_1.shape[1]

for e in np.arange(0,n_cols,1):

    data = dfg_1.iloc[:,e].dropna().reset_index().copy()
    data =pd.Series(data.values.ravel())


    # Plot for comparison
    plt.figure(figsize=(12,8))
    ax = data.plot(kind='hist', bins=10, normed=True, alpha=0.5)
    # Save plot limits
    dataYLim = ax.get_ylim()

    # Find best fit distribution
    best_fit_name, best_fit_params = best_fit_distribution(data, 200, ax)
    best_dist = getattr(st, best_fit_name)

    # Update plots
    ax.set_ylim(dataYLim)
    ax.set_title(dfg_1.columns[e] + u'\n All Fitted Distributions')
    ax.set_xlabel('')
    ax.set_ylabel('Frequency')

    # Make PDF with best params 
    pdf = make_pdf(best_dist, best_fit_params)

    # Display
    plt.figure(figsize=(12,8))
    ax = pdf.plot(lw=2, label='PDF', legend=True)
    data.plot(kind='hist', bins=10, normed=True, alpha=0.5, label='Data', legend=True, ax=ax)

    param_names = (best_dist.shapes + ', loc, scale').split(', ') if best_dist.shapes else ['loc', 'scale']
    param_str = ', '.join(['{}={:0.2f}'.format(k,v) for k,v in zip(param_names, best_fit_params)])
    dist_str = '{}({})'.format(best_fit_name, param_str)

    ax.set_title(dfg_1.columns[e] + u'\n' + dist_str)
    ax.set_xlabel('')
    ax.set_ylabel('Frequency')

# %%
# Plotto il grafico multiplo di correlazione

corrgraph(dfg, 'corr_3')

# %%
#  Seleziono colonne utili

dfg=dfxls.filter(regex='(Pressure excavation chamber 5|Pressure excavation chamber 8|Fill level|grout injection pressure|\
Line 1 grout injection amount|Line 1 grout injection flow)')

# Semplifico il nome delle colonne
col_ls = dfg.columns.tolist()
col_ls = list(map(lambda x: str.replace(x,"Pressure excavation chamber ","Pr_Ex_Ch_"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Fill level working chamber","Fill_Lev_WCh"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Air Flow in Normal m3/min","Air_Flow_in"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Line 1 grout injection ","L1_Gr_in_"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"pressure","Pr"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Line ","L_"),col_ls))
dfg.columns = col_ls

# Verifico i risultati dell'operazione
print (col_ls)

# %%
###########         SALVA IL DATABASE

# %%
import h5py
dfxls.to_hdf('20200107.h5', key='losses')
dfxls.to_hdf('20200107.h5', key='losses')
dfxls_hdf = pd.read_hdf('20200107.h5', key='losses')

# %% [markdown]
# ###          TROVA LE DISTRIBUZIONI DELLA Working Chamber 5

# %%
from sklearn import mixture

# %%
dfg=dfxls.filter(regex='(Pressure excavation chamber 5)')
X=np.array(dfg.iloc[:,0]).reshape(-1, 1)

# %%
n_comp = 3
g = mixture.GaussianMixture(n_components=n_comp,covariance_type='full')
g.fit(X)
weights = g.weights_
means = g.means_
covars = g.covariances_
#  Plotta le distribuzioni
fig = plt.figure(figsize=(20,10))
plt.hist(X, bins=100, histtype='bar', density=True, ec='red', alpha=0.5)

f_axis = X.copy().ravel()
f_axis.sort()

for i in np.arange(0,n_comp,1):
    plt.plot(f_axis,weights[i]*stats.norm.pdf(f_axis,means[i],np.sqrt(covars[i])).ravel(), c='red')

plt.rcParams['agg.path.chunksize'] = 10000

plt.grid()
plt.show()

# %%
clarr

# %%
labels

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

labels = g.predict(X)
Y=np.array(dfg.index)

ax.scatter(Y,X[:, 0], c=labels, s=10, cmap='viridis')


classls = list(set(labels))

# for ii in classls:
#     ax.scatter([],[],c=ii, s=10, cmap='viridis')

clarr = np.array(classls)


for i in clarr:
    ax.scatter([],[],c=clarr[i],s=10, cmap='viridis')

plt.legend()

# %%
#  Seleziono colonne utili

dfg=dfxls.filter(regex='(Pressure excavation chamber 5|Pressure excavation chamber 8|Fill level|grout injection pressure|\
Line 1 grout injection amount|Line 1 grout injection flow)')

# Semplifico il nome delle colonne
col_ls = dfg.columns.tolist()
col_ls = list(map(lambda x: str.replace(x,"Pressure excavation chamber ","Pr_Ex_Ch_"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Fill level working chamber","Fill_Lev_WCh"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Air Flow in Normal m3/min","Air_Flow_in"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Line 1 grout injection ","L1_Gr_in_"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"pressure","Pr"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Line ","L_"),col_ls))
dfg.columns = col_ls

# Verifico i risultati dell'operazione
print (col_ls)

dfg['classi']=labels
dfg=dfg[dfg.classi==1]

# %%
# Plotto il grafico multiplo di correlazione

corrgraph(dfg, 'corr_class')

# %%
dfg=dfxls.filter(regex='(Pressure excavation chamber|Fill level)')

col_ls = dfg.columns.tolist()
col_ls = list(map(lambda x: str.replace(x,"Pressure excavation chamber ","Pr_Ex_Ch_"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Fill level working chamber","Fill_Lev_WCh"),col_ls))
dfg.columns = col_ls
dfg['classi']=labels
dfg=dfg[dfg.classi==1]

# %%
# Plotto il grafico multiplo di correlazione

corrgraph(dfg, 'corr_class')

# %%
dfg.Pr_ex

# %% [markdown]
# ### TROVA LE DISTRIBUZIONI DELLA Working Chamber 4

# %%
dfg=dfxls.filter(regex='(Pressure excavation chamber 4)')
X=np.array(dfg.iloc[:,0]).reshape(-1, 1)

# %%
n_comp = 3
g = mixture.GaussianMixture(n_components=n_comp,covariance_type='full')
g.fit(X)
weights = g.weights_
means = g.means_
covars = g.covariances_
#  Plotta le distribuzioni
fig = plt.figure(figsize=(20,10))
plt.hist(X, bins=100, histtype='bar', density=True, ec='red', alpha=0.5)

f_axis = X.copy().ravel()
f_axis.sort()

for i in np.arange(0,n_comp,1):
    plt.plot(f_axis,weights[i]*stats.norm.pdf(f_axis,means[i],np.sqrt(covars[i])).ravel(), c='red')

plt.rcParams['agg.path.chunksize'] = 10000

plt.grid()
plt.show()

# %%
means, covars

# %%
labels = g.predict(X)
Y=np.array(dfg.index)
fig = plt.figure(figsize=(20,10))
plt.scatter(Y,X[:, 0], c=labels, s=10, cmap='viridis')
plt.legend(loc='upper left', frameon=False)

# %%
dfg=dfxls.filter(regex='(Pressure excavation chamber|Fill level)')

col_ls = dfg.columns.tolist()
col_ls = list(map(lambda x: str.replace(x,"Pressure excavation chamber ","Pr_Ex_Ch_"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Fill level working chamber","Fill_Lev_WCh"),col_ls))
dfg.columns = col_ls
dfg['classi']=labels
dfg=dfg[dfg.classi==0]

# %%
# verifico tramite plot che la classe '0' è la sclasse di quando la macchina è in funzione

fig = plt.figure(figsize=(20,10))
plt.scatter(dfg.index,dfg['Pr_Ex_Ch_4 [bar]'], c=dfg.classi, s=10, cmap='viridis',label=dfg.classi)
dfxls.iloc[:,[0,5]].plot()

        fig = plt.figure(figsize=(20,10))

        ax = fig.add_subplot(121, projection='3d')
        ax1 = fig.add_subplot(122, projection='3d')

        ax.set_xlabel("x")
        ax.set_ylabel("y") 
        
        ax.set_xlim(-1,1)
        ax.set_ylim(1.5,0)

# %%
# Plotto il grafico multiplo di correlazione

corrgraph(dfg.loc[:, dfg.columns != 'classi'], 'corr_class')

# %%
dfg.loc[:, dfg.columns != 'classi']

# %%
dfg.columns

# %%
dfxls.columns

# %% [markdown]
# ## Filtro:
# - Advance speed [mm/min] = 0
# - Torque cutting wheel [MNm] = 0

# %%
dfxls.describe()['Advance speed [mm/min]']

# %%
dfxls.describe()['Torque cutting wheel [MNm]']

# %%
dfg=dfxls[(dfxls['Torque cutting wheel [MNm]']==0) & (dfxls['Advance speed [mm/min]']==0)].filter(regex='(Pressure excavation chamber|Fill level)')
col_ls = dfg.columns.tolist()
col_ls = list(map(lambda x: str.replace(x,"Pressure excavation chamber ","Pr_Ex_Ch_"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Fill level working chamber","Fill_Lev_WCh"),col_ls))
dfg.columns = col_ls

# %%
# Plotto il grafico multiplo di correlazione

corrgraph(dfg.loc[:, dfg.columns != 'classi'], 'corr_class')

# %% [markdown]
# ## Filtro:
# - Advance speed [mm/min] = 0
# - Torque cutting wheel [MNm] # 0

# %%
dfg=dfxls[(dfxls['Torque cutting wheel [MNm]']<=0) & (dfxls['Advance speed [mm/min]']!=0)].filter(regex='(Pressure excavation chamber|Fill level)')
col_ls = dfg.columns.tolist()
col_ls = list(map(lambda x: str.replace(x,"Pressure excavation chamber ","Pr_Ex_Ch_"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Fill level working chamber","Fill_Lev_WCh"),col_ls))
dfg.columns = col_ls

# %%
# Plotto il grafico multiplo di correlazione

corrgraph(dfg.loc[:, dfg.columns != 'classi'], 'corr_class')

# %% [markdown]
# ## Filtro:
# - Advance speed [mm/min] # 0
# - Torque cutting wheel [MNm] # 0

# %%
dfg=dfxls[(dfxls['Torque cutting wheel [MNm]']!=0) & (dfxls['Advance speed [mm/min]']!=0)].filter(regex='(Pressure excavation chamber|Fill level)')
col_ls = dfg.columns.tolist()
col_ls = list(map(lambda x: str.replace(x,"Pressure excavation chamber ","Pr_Ex_Ch_"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Fill level working chamber","Fill_Lev_WCh"),col_ls))
dfg.columns = col_ls

# %%
# Plotto il grafico multiplo di correlazione

corrgraph(dfg.loc[:, dfg.columns != 'classi'], 'corr_class')

# %% [markdown]
# ## Plot only inside 95 and  5% confidence intervals

# %%
dfg=dfxls[(dfxls['Torque cutting wheel [MNm]']!=0) & (dfxls['Advance speed [mm/min]']!=0)]
dfg.describe()['Torque cutting wheel [MNm]']

# %%
dfg=dfxls[(dfxls['Torque cutting wheel [MNm]']!=0) & (dfxls['Advance speed [mm/min]']!=0)]
dfg.describe()['Advance speed [mm/min]']

# %% [markdown]
# ### Calcolo gli intervallli di confidenza

# %%
from scipy import stats
import scipy.stats

dfg=dfxls[(dfxls['Torque cutting wheel [MNm]']!=0) & (dfxls['Advance speed [mm/min]']!=0)]

mean = dfg.mean()
std = dfg.std()

n= dfg.shape[0]
f_inf = std / np.sqrt(n) * stats.t.ppf(1-0.25/2, n - 1)
f_sup = std / np.sqrt(n) * stats.t.ppf(1-0.25/2, n - 1)

def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

f_inf_torq=mean_confidence_interval(dfg['Torque cutting wheel [MNm]'],0.9)[1]
f_sup_torq=mean_confidence_interval(dfg['Torque cutting wheel [MNm]'],0.9)[2]
f_inf_adv=mean_confidence_interval(dfg['Advance speed [mm/min]'],0.9)[1]
f_sup_adv=mean_confidence_interval(dfg['Advance speed [mm/min]'],0.9)[2]

f_min_torq = dfg['Torque cutting wheel [MNm]'].min()
f_min_adv = dfg['Advance speed [mm/min]'].min()

f_min_torq25 = dfg.describe()['Torque cutting wheel [MNm]'][4]
f_min_adv25 = dfg.describe()['Advance speed [mm/min]'][4]

dfg.describe()['Advance speed [mm/min]']
print('dfg shape {}'.format(dfg.shape))
print('Torque cutting wheel [MNm]: {}'.format(f_inf_torq))
print('Torque cutting wheel [MNm]: {}'.format(f_sup_torq))
print('Advance speed [mm/min]: {}'.format(f_inf_adv))
print('Advance speed [mm/min]: {}'.format(f_sup_adv))

print('Torque cutting wheel [MNm] min: {}'.format(f_min_torq))
print('Advance speed [mm/min] min: {}'.format(f_min_adv))

print('Torque cutting wheel [MNm] min25: {}'.format(f_min_torq25))
print('Advance speed [mm/min] min25: {}'.format(f_min_adv25))

# %%
dfg=dfxls[(dfxls['Torque cutting wheel [MNm]']>f_min_torq25) &
          (dfxls['Advance speed [mm/min]']>f_min_adv25)].filter(regex='(Pressure excavation chamber|Fill level)')
col_ls = dfg.columns.tolist()
col_ls = list(map(lambda x: str.replace(x,"Pressure excavation chamber ","Pr_Ex_Ch_"),col_ls))
col_ls = list(map(lambda x: str.replace(x,"Fill level working chamber","Fill_Lev_WCh"),col_ls))
dfg.columns = col_ls

print('dfg shape {}'.format(dfg.shape))

# %%
# Plotto il grafico multiplo di correlazione

corrgraph(dfg.loc[:, dfg.columns != 'classi'], 'corr_class')
